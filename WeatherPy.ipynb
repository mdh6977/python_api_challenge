# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 607

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = "https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grytviken
# City not found. Skipping...
# Processing Record 2 of Set 1 | sao tome
# City not found. Skipping...
# Processing Record 3 of Set 1 | ribeira grande
# City not found. Skipping...
# Processing Record 4 of Set 1 | vorgashor
# City not found. Skipping...
# Processing Record 5 of Set 1 | constantia
# City not found. Skipping...
# Processing Record 6 of Set 1 | kitui
# City not found. Skipping...
# Processing Record 7 of Set 1 | port-aux-francais
# City not found. Skipping...
# Processing Record 8 of Set 1 | tiksi
# City not found. Skipping...
# Processing Record 9 of Set 1 | uttar char fasson
# City not found. Skipping...
# Processing Record 10 of Set 1 | nishinoomote
# City not found. Skipping...
# Processing Record 11 of Set 1 | waitangi
# City not found. Skipping...
# Processing Record 12 of Set 1 | qaqortoq
# City not found. Skipping...
# Processing Record 13 of Set 1 | puerto natales
# City not found. Skipping...
# Processing Record 14 of Set 1 | igarka
# City not found. Skipping...
# Processing Record 15 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 16 of Set 1 | rokycany
# City not found. Skipping...
# Processing Record 17 of Set 1 | margaret river
# City not found. Skipping...
# Processing Record 18 of Set 1 | port elizabeth
# City not found. Skipping...
# Processing Record 19 of Set 1 | christchurch
# City not found. Skipping...
# Processing Record 20 of Set 1 | qarazhal
# City not found. Skipping...
# Processing Record 21 of Set 1 | kuqa
# City not found. Skipping...
# Processing Record 22 of Set 1 | tanumah
# City not found. Skipping...
# Processing Record 23 of Set 1 | grand falls-windsor
# City not found. Skipping...
# Processing Record 24 of Set 1 | paramaribo
# City not found. Skipping...
# Processing Record 25 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 26 of Set 1 | deniliquin
# City not found. Skipping...
# Processing Record 27 of Set 1 | susuman
# City not found. Skipping...
# Processing Record 28 of Set 1 | neiafu
# City not found. Skipping...
# Processing Record 29 of Set 1 | argo
# City not found. Skipping...
# Processing Record 30 of Set 1 | yuzhno-kurilsk
# City not found. Skipping...
# Processing Record 31 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 32 of Set 1 | mount gambier
# City not found. Skipping...
# Processing Record 33 of Set 1 | kapuskasing
# City not found. Skipping...
# Processing Record 34 of Set 1 | adamstown
# City not found. Skipping...
# Processing Record 35 of Set 1 | port alfred
# City not found. Skipping...
# Processing Record 36 of Set 1 | itapuranga
# City not found. Skipping...
# Processing Record 37 of Set 1 | laojunmiao
# City not found. Skipping...
# Processing Record 38 of Set 1 | weno
# City not found. Skipping...
# Processing Record 39 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 40 of Set 1 | cambria
# City not found. Skipping...
# Processing Record 41 of Set 1 | semey
# City not found. Skipping...
# Processing Record 42 of Set 1 | kerikeri
# City not found. Skipping...
# Processing Record 43 of Set 1 | magadan
# City not found. Skipping...
# Processing Record 44 of Set 1 | velikiye luki
# City not found. Skipping...
# Processing Record 45 of Set 1 | batabano
# City not found. Skipping...
# Processing Record 46 of Set 1 | tugulym
# City not found. Skipping...
# Processing Record 47 of Set 1 | newman
# City not found. Skipping...
# Processing Record 48 of Set 1 | ballina
# City not found. Skipping...
# Processing Record 49 of Set 1 | kinablangan
# City not found. Skipping...
# Processing Record 50 of Set 1 | talnakh
# City not found. Skipping...
# Processing Record 0 of Set 2 | padang
# City not found. Skipping...
# Processing Record 1 of Set 2 | crane
# City not found. Skipping...
# Processing Record 2 of Set 2 | jamestown
# City not found. Skipping...
# Processing Record 3 of Set 2 | albany
# City not found. Skipping...
# Processing Record 4 of Set 2 | kindu
# City not found. Skipping...
# Processing Record 5 of Set 2 | vadso
# City not found. Skipping...
# Processing Record 6 of Set 2 | la'ie
# City not found. Skipping...
# Processing Record 7 of Set 2 | ribeira brava
# City not found. Skipping...
# Processing Record 8 of Set 2 | puerto ayora
# City not found. Skipping...
# Processing Record 9 of Set 2 | udachny
# City not found. Skipping...
# Processing Record 10 of Set 2 | darwin
# City not found. Skipping...
# Processing Record 11 of Set 2 | luderitz
# City not found. Skipping...
# Processing Record 12 of Set 2 | punta arenas
# City not found. Skipping...
# Processing Record 13 of Set 2 | usinsk
# City not found. Skipping...
# Processing Record 14 of Set 2 | forster
# City not found. Skipping...
# Processing Record 15 of Set 2 | hermanus
# City not found. Skipping...
# Processing Record 16 of Set 2 | blackmans bay
# City not found. Skipping...
# Processing Record 17 of Set 2 | conduaga
# City not found. Skipping...
# Processing Record 18 of Set 2 | omutinskiy
# City not found. Skipping...
# Processing Record 19 of Set 2 | hamilton
# City not found. Skipping...
# Processing Record 20 of Set 2 | yagry
# City not found. Skipping...
# Processing Record 21 of Set 2 | celestun
# City not found. Skipping...
# Processing Record 22 of Set 2 | avarua
# City not found. Skipping...
# Processing Record 23 of Set 2 | invercargill
# City not found. Skipping...
# Processing Record 24 of Set 2 | kodiak
# City not found. Skipping...
# Processing Record 25 of Set 2 | cabo san lucas
# City not found. Skipping...
# Processing Record 26 of Set 2 | pisco
# City not found. Skipping...
# Processing Record 27 of Set 2 | sona
# City not found. Skipping...
# Processing Record 28 of Set 2 | san patricio
# City not found. Skipping...
# Processing Record 29 of Set 2 | utrik
# City not found. Skipping...
# Processing Record 30 of Set 2 | whitehorse
# City not found. Skipping...
# Processing Record 31 of Set 2 | uturoa
# City not found. Skipping...
# Processing Record 32 of Set 2 | kimbe
# City not found. Skipping...
# Processing Record 33 of Set 2 | olonkinbyen
# City not found. Skipping...
# Processing Record 34 of Set 2 | clarksville
# City not found. Skipping...
# Processing Record 35 of Set 2 | caleta de carquin
# City not found. Skipping...
# Processing Record 36 of Set 2 | yunak
# City not found. Skipping...
# Processing Record 37 of Set 2 | nukunonu
# City not found. Skipping...
# Processing Record 38 of Set 2 | macapa
# City not found. Skipping...
# Processing Record 39 of Set 2 | northam
# City not found. Skipping...
# Processing Record 40 of Set 2 | viet tri
# City not found. Skipping...
# Processing Record 41 of Set 2 | vozhega
# City not found. Skipping...
# Processing Record 42 of Set 2 | bethel
# City not found. Skipping...
# Processing Record 43 of Set 2 | n'zeto
# City not found. Skipping...
# Processing Record 44 of Set 2 | minas de marcona
# City not found. Skipping...
# Processing Record 45 of Set 2 | glace bay
# City not found. Skipping...
# Processing Record 46 of Set 2 | acapulco de juarez
# City not found. Skipping...
# Processing Record 47 of Set 2 | college
# City not found. Skipping...
# Processing Record 48 of Set 2 | novodvinsk
# City not found. Skipping...
# Processing Record 49 of Set 2 | kaa-khem
# City not found. Skipping...
# Processing Record 0 of Set 3 | mutsu
# City not found. Skipping...
# Processing Record 1 of Set 3 | acarau
# City not found. Skipping...
# Processing Record 2 of Set 3 | kirkwall
# City not found. Skipping...
# Processing Record 3 of Set 3 | vila velha
# City not found. Skipping...
# Processing Record 4 of Set 3 | carnarvon
# City not found. Skipping...
# Processing Record 5 of Set 3 | thompson
# City not found. Skipping...
# Processing Record 6 of Set 3 | waingapu
# City not found. Skipping...
# Processing Record 7 of Set 3 | sisimiut
# City not found. Skipping...
# Processing Record 8 of Set 3 | charters towers
# City not found. Skipping...
# Processing Record 9 of Set 3 | hacienda huancane
# City not found. Skipping...
# Processing Record 10 of Set 3 | muscat
# City not found. Skipping...
# Processing Record 11 of Set 3 | kalispell
# City not found. Skipping...
# Processing Record 12 of Set 3 | kapa'a
# City not found. Skipping...
# Processing Record 13 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 14 of Set 3 | topolobampo
# City not found. Skipping...
# Processing Record 15 of Set 3 | isafjordur
# City not found. Skipping...
# Processing Record 16 of Set 3 | stanley
# City not found. Skipping...
# Processing Record 17 of Set 3 | edinburgh of the seven seas
# City not found. Skipping...
# Processing Record 18 of Set 3 | bamboo flat
# City not found. Skipping...
# Processing Record 19 of Set 3 | tibanbang
# City not found. Skipping...
# Processing Record 20 of Set 3 | khandyga
# City not found. Skipping...
# Processing Record 21 of Set 3 | papatowai
# City not found. Skipping...
# Processing Record 22 of Set 3 | tura
# City not found. Skipping...
# Processing Record 23 of Set 3 | hami
# City not found. Skipping...
# Processing Record 24 of Set 3 | mitsamiouli
# City not found. Skipping...
# Processing Record 25 of Set 3 | laibin
# City not found. Skipping...
# Processing Record 26 of Set 3 | naze
# City not found. Skipping...
# Processing Record 27 of Set 3 | bilibino
# City not found. Skipping...
# Processing Record 28 of Set 3 | san juan nepomuceno
# City not found. Skipping...
# Processing Record 29 of Set 3 | umatilla
# City not found. Skipping...
# Processing Record 30 of Set 3 | nogliki
# City not found. Skipping...
# Processing Record 31 of Set 3 | arraial do cabo
# City not found. Skipping...
# Processing Record 32 of Set 3 | tolanaro
# City not found. Skipping...
# Processing Record 33 of Set 3 | hailey
# City not found. Skipping...
# Processing Record 34 of Set 3 | bubaque
# City not found. Skipping...
# Processing Record 35 of Set 3 | altai
# City not found. Skipping...
# Processing Record 36 of Set 3 | mutuali
# City not found. Skipping...
# Processing Record 37 of Set 3 | badger
# City not found. Skipping...
# Processing Record 38 of Set 3 | skovorodino
# City not found. Skipping...
# Processing Record 39 of Set 3 | lompoc
# City not found. Skipping...
# Processing Record 40 of Set 3 | zuunmod
# City not found. Skipping...
# Processing Record 41 of Set 3 | mil'kovo
# City not found. Skipping...
# Processing Record 42 of Set 3 | port mathurin
# City not found. Skipping...
# Processing Record 43 of Set 3 | wailua homesteads
# City not found. Skipping...
# Processing Record 44 of Set 3 | iqaluit
# City not found. Skipping...
# Processing Record 45 of Set 3 | shilin
# City not found. Skipping...
# Processing Record 46 of Set 3 | kushikino
# City not found. Skipping...
# Processing Record 47 of Set 3 | longyearbyen
# City not found. Skipping...
# Processing Record 48 of Set 3 | inverell
# City not found. Skipping...
# Processing Record 49 of Set 3 | scarborough
# City not found. Skipping...
# Processing Record 0 of Set 4 | st. john's
# City not found. Skipping...
# Processing Record 1 of Set 4 | ilulissat
# City not found. Skipping...
# Processing Record 2 of Set 4 | huilong
# City not found. Skipping...
# Processing Record 3 of Set 4 | genhe
# City not found. Skipping...
# Processing Record 4 of Set 4 | saipan
# City not found. Skipping...
# Processing Record 5 of Set 4 | zhezqazghan
# City not found. Skipping...
# Processing Record 6 of Set 4 | sarangani
# City not found. Skipping...
# Processing Record 7 of Set 4 | martapura
# City not found. Skipping...
# Processing Record 8 of Set 4 | acajutla
# City not found. Skipping...
# Processing Record 9 of Set 4 | saint-pierre
# City not found. Skipping...
# Processing Record 10 of Set 4 | kosh-agach
# City not found. Skipping...
# Processing Record 11 of Set 4 | menominee
# City not found. Skipping...
# Processing Record 12 of Set 4 | tulare
# City not found. Skipping...
# Processing Record 13 of Set 4 | chinde
# City not found. Skipping...
# Processing Record 14 of Set 4 | nadym
# City not found. Skipping...
# Processing Record 15 of Set 4 | boca suno
# City not found. Skipping...
# Processing Record 16 of Set 4 | lihue
# City not found. Skipping...
# Processing Record 17 of Set 4 | nguigmi
# City not found. Skipping...
# Processing Record 18 of Set 4 | illizi
# City not found. Skipping...
# Processing Record 19 of Set 4 | mokhsogollokh
# City not found. Skipping...
# Processing Record 20 of Set 4 | boguchany
# City not found. Skipping...
# Processing Record 21 of Set 4 | undurkhaan
# City not found. Skipping...
# Processing Record 22 of Set 4 | pangai
# City not found. Skipping...
# Processing Record 23 of Set 4 | sao joao da barra
# City not found. Skipping...
# Processing Record 24 of Set 4 | nabire
# City not found. Skipping...
# Processing Record 25 of Set 4 | saint-joseph
# City not found. Skipping...
# Processing Record 26 of Set 4 | nantucket
# City not found. Skipping...
# Processing Record 27 of Set 4 | hithadhoo
# City not found. Skipping...
# Processing Record 28 of Set 4 | san sebastian de la gomera
# City not found. Skipping...
# Processing Record 29 of Set 4 | pavlodar
# City not found. Skipping...
# Processing Record 30 of Set 4 | west island
# City not found. Skipping...
# Processing Record 31 of Set 4 | yeppoon
# City not found. Skipping...
# Processing Record 32 of Set 4 | quellon
# City not found. Skipping...
# Processing Record 33 of Set 4 | umatac village
# City not found. Skipping...
# Processing Record 34 of Set 4 | bargaal
# City not found. Skipping...
# Processing Record 35 of Set 4 | kailua-kona
# City not found. Skipping...
# Processing Record 36 of Set 4 | ejigbo
# City not found. Skipping...
# Processing Record 37 of Set 4 | arkhangel'sk
# City not found. Skipping...
# Processing Record 38 of Set 4 | zhengjiatun
# City not found. Skipping...
# Processing Record 39 of Set 4 | la crosse
# City not found. Skipping...
# Processing Record 40 of Set 4 | asau
# City not found. Skipping...
# Processing Record 41 of Set 4 | caldwell
# City not found. Skipping...
# Processing Record 42 of Set 4 | nagireddipalli
# City not found. Skipping...
# Processing Record 43 of Set 4 | haiku-pauwela
# City not found. Skipping...
# Processing Record 44 of Set 4 | monrovia
# City not found. Skipping...
# Processing Record 45 of Set 4 | shakhun'ya
# City not found. Skipping...
# Processing Record 46 of Set 4 | klyuchi
# City not found. Skipping...
# Processing Record 47 of Set 4 | codrington
# City not found. Skipping...
# Processing Record 48 of Set 4 | tisaiyanvilai
# City not found. Skipping...
# Processing Record 49 of Set 4 | saint-pierre-d'oleron
# City not found. Skipping...
# Processing Record 0 of Set 5 | hotan
# City not found. Skipping...
# Processing Record 1 of Set 5 | tai'an
# City not found. Skipping...
# Processing Record 2 of Set 5 | lautoka
# City not found. Skipping...
# Processing Record 3 of Set 5 | luwuk
# City not found. Skipping...
# Processing Record 4 of Set 5 | nanao
# City not found. Skipping...
# Processing Record 5 of Set 5 | pont rouge
# City not found. Skipping...
# Processing Record 6 of Set 5 | biloxi
# City not found. Skipping...
# Processing Record 7 of Set 5 | katsuura
# City not found. Skipping...
# Processing Record 8 of Set 5 | noumea
# City not found. Skipping...
# Processing Record 9 of Set 5 | kulim
# City not found. Skipping...
# Processing Record 10 of Set 5 | ungsang-nodongjagu
# City not found. Skipping...
# Processing Record 11 of Set 5 | sinabang
# City not found. Skipping...
# Processing Record 12 of Set 5 | suva
# City not found. Skipping...
# Processing Record 13 of Set 5 | ust-nera
# City not found. Skipping...
# Processing Record 14 of Set 5 | ban tak
# City not found. Skipping...
# Processing Record 15 of Set 5 | kaifeng
# City not found. Skipping...
# Processing Record 16 of Set 5 | gonabad
# City not found. Skipping...
# Processing Record 17 of Set 5 | cockburn town
# City not found. Skipping...
# Processing Record 18 of Set 5 | ranau
# City not found. Skipping...
# Processing Record 19 of Set 5 | luanda
# City not found. Skipping...
# Processing Record 20 of Set 5 | alaghsas
# City not found. Skipping...
# Processing Record 21 of Set 5 | fort bragg
# City not found. Skipping...
# Processing Record 22 of Set 5 | avdiyivka
# City not found. Skipping...
# Processing Record 23 of Set 5 | bijapur
# City not found. Skipping...
# Processing Record 24 of Set 5 | kolonia
# City not found. Skipping...
# Processing Record 25 of Set 5 | enewetak
# City not found. Skipping...
# Processing Record 26 of Set 5 | guanica
# City not found. Skipping...
# Processing Record 27 of Set 5 | randers
# City not found. Skipping...
# Processing Record 28 of Set 5 | tazovsky
# City not found. Skipping...
# Processing Record 29 of Set 5 | sosnogorsk
# City not found. Skipping...
# Processing Record 30 of Set 5 | geraldton
# City not found. Skipping...
# Processing Record 31 of Set 5 | kingston
# City not found. Skipping...
# Processing Record 32 of Set 5 | maues
# City not found. Skipping...
# Processing Record 33 of Set 5 | missoula
# City not found. Skipping...
# Processing Record 34 of Set 5 | kraljevo
# City not found. Skipping...
# Processing Record 35 of Set 5 | eenhana
# City not found. Skipping...
# Processing Record 36 of Set 5 | huanuco
# City not found. Skipping...
# Processing Record 37 of Set 5 | georgetown
# City not found. Skipping...
# Processing Record 38 of Set 5 | margate
# City not found. Skipping...
# Processing Record 39 of Set 5 | fort-shevchenko
# City not found. Skipping...
# Processing Record 40 of Set 5 | port lincoln
# City not found. Skipping...
# Processing Record 41 of Set 5 | kuala perlis
# City not found. Skipping...
# Processing Record 42 of Set 5 | razdol'noye
# City not found. Skipping...
# Processing Record 43 of Set 5 | aasiaat
# City not found. Skipping...
# Processing Record 44 of Set 5 | cihanbeyli
# City not found. Skipping...
# Processing Record 45 of Set 5 | fereydun kenar
# City not found. Skipping...
# Processing Record 46 of Set 5 | north las vegas
# City not found. Skipping...
# Processing Record 47 of Set 5 | ust-tsilma
# City not found. Skipping...
# Processing Record 48 of Set 5 | polonne
# City not found. Skipping...
# Processing Record 49 of Set 5 | sucre
# City not found. Skipping...
# Processing Record 0 of Set 6 | anloga
# City not found. Skipping...
# Processing Record 1 of Set 6 | touros
# City not found. Skipping...
# Processing Record 2 of Set 6 | veymandoo
# City not found. Skipping...
# Processing Record 3 of Set 6 | el fasher
# City not found. Skipping...
# Processing Record 4 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 5 of Set 6 | krasnobrodskiy
# City not found. Skipping...
# Processing Record 6 of Set 6 | yigo village
# City not found. Skipping...
# Processing Record 7 of Set 6 | sitka
# City not found. Skipping...
# Processing Record 8 of Set 6 | lebu
# City not found. Skipping...
# Processing Record 9 of Set 6 | llandudno
# City not found. Skipping...
# Processing Record 10 of Set 6 | houghton
# City not found. Skipping...
# Processing Record 11 of Set 6 | la passe
# City not found. Skipping...
# Processing Record 12 of Set 6 | dubovka
# City not found. Skipping...
# Processing Record 13 of Set 6 | parang
# City not found. Skipping...
# Processing Record 14 of Set 6 | sampit
# City not found. Skipping...
# Processing Record 15 of Set 6 | adis zemen
# City not found. Skipping...
# Processing Record 16 of Set 6 | torghay
# City not found. Skipping...
# Processing Record 17 of Set 6 | isla del bosque
# City not found. Skipping...
# Processing Record 18 of Set 6 | sevsk
# City not found. Skipping...
# Processing Record 19 of Set 6 | nouadhibou
# City not found. Skipping...
# Processing Record 20 of Set 6 | la sarre
# City not found. Skipping...
# Processing Record 21 of Set 6 | dalian
# City not found. Skipping...
# Processing Record 22 of Set 6 | smithers
# City not found. Skipping...
# Processing Record 23 of Set 6 | chegdomyn
# City not found. Skipping...
# Processing Record 24 of Set 6 | felahiye
# City not found. Skipping...
# Processing Record 25 of Set 6 | mount isa
# City not found. Skipping...
# Processing Record 26 of Set 6 | tobi village
# City not found. Skipping...
# Processing Record 27 of Set 6 | nemuro
# City not found. Skipping...
# Processing Record 28 of Set 6 | ayaguz
# City not found. Skipping...
# Processing Record 29 of Set 6 | petropavlovsk-kamchatsky
# City not found. Skipping...
# Processing Record 30 of Set 6 | talara
# City not found. Skipping...
# Processing Record 31 of Set 6 | quiberon
# City not found. Skipping...
# Processing Record 32 of Set 6 | yelizovo
# City not found. Skipping...
# Processing Record 33 of Set 6 | novyy turtkul'
# City not found. Skipping...
# Processing Record 34 of Set 6 | chadron
# City not found. Skipping...
# Processing Record 35 of Set 6 | usogorsk
# City not found. Skipping...
# Processing Record 36 of Set 6 | piti village
# City not found. Skipping...
# Processing Record 37 of Set 6 | iskateley
# City not found. Skipping...
# Processing Record 38 of Set 6 | anna regina
# City not found. Skipping...
# Processing Record 39 of Set 6 | kill devil hills
# City not found. Skipping...
# Processing Record 40 of Set 6 | holualoa
# City not found. Skipping...
# Processing Record 41 of Set 6 | prado
# City not found. Skipping...
# Processing Record 42 of Set 6 | paka
# City not found. Skipping...
# Processing Record 43 of Set 6 | hawaiian paradise park
# City not found. Skipping...
# Processing Record 44 of Set 6 | nyurba
# City not found. Skipping...
# Processing Record 45 of Set 6 | strezhevoy
# City not found. Skipping...
# Processing Record 46 of Set 6 | kulia village
# City not found. Skipping...
# Processing Record 47 of Set 6 | howrah
# City not found. Skipping...
# Processing Record 48 of Set 6 | kiboga
# City not found. Skipping...
# Processing Record 49 of Set 6 | tsiombe
# City not found. Skipping...
# Processing Record 0 of Set 7 | vilyuchinsk
# City not found. Skipping...
# Processing Record 1 of Set 7 | lazaro cardenas
# City not found. Skipping...
# Processing Record 2 of Set 7 | belmar
# City not found. Skipping...
# Processing Record 3 of Set 7 | itoman
# City not found. Skipping...
# Processing Record 4 of Set 7 | i-n-salah
# City not found. Skipping...
# Processing Record 5 of Set 7 | flying fish cove
# City not found. Skipping...
# Processing Record 6 of Set 7 | reyes
# City not found. Skipping...
# Processing Record 7 of Set 7 | tofol
# City not found. Skipping...
# Processing Record 8 of Set 7 | solok
# City not found. Skipping...
# Processing Record 9 of Set 7 | klaksvik
# City not found. Skipping...
# Processing Record 10 of Set 7 | gumrak
# City not found. Skipping...
# Processing Record 11 of Set 7 | novo aripuana
# City not found. Skipping...
# Processing Record 12 of Set 7 | lata
# City not found. Skipping...
# Processing Record 13 of Set 7 | tsengel
# City not found. Skipping...
# Processing Record 14 of Set 7 | dolinsk
# City not found. Skipping...
# Processing Record 15 of Set 7 | timbuktu
# City not found. Skipping...
# Processing Record 16 of Set 7 | bintulu
# City not found. Skipping...
# Processing Record 17 of Set 7 | verkhnevilyuysk
# City not found. Skipping...
# Processing Record 18 of Set 7 | baijiantan
# City not found. Skipping...
# Processing Record 19 of Set 7 | north bend
# City not found. Skipping...
# Processing Record 20 of Set 7 | gillette
# City not found. Skipping...
# Processing Record 21 of Set 7 | khanbari
# City not found. Skipping...
# Processing Record 22 of Set 7 | port blair
# City not found. Skipping...
# Processing Record 23 of Set 7 | dzuunmod
# City not found. Skipping...
# Processing Record 24 of Set 7 | pachino
# City not found. Skipping...
# Processing Record 25 of Set 7 | aberdeen
# City not found. Skipping...
# Processing Record 26 of Set 7 | colonia
# City not found. Skipping...
# Processing Record 27 of Set 7 | constitucion
# City not found. Skipping...
# Processing Record 28 of Set 7 | pokhvistnevo
# City not found. Skipping...
# Processing Record 29 of Set 7 | al kharijah
# City not found. Skipping...
# Processing Record 30 of Set 7 | alta
# City not found. Skipping...
# Processing Record 31 of Set 7 | jayapura
# City not found. Skipping...
# Processing Record 32 of Set 7 | port isabel
# City not found. Skipping...
# Processing Record 33 of Set 7 | makaha
# City not found. Skipping...
# Processing Record 34 of Set 7 | krasnozerskoye
# City not found. Skipping...
# Processing Record 35 of Set 7 | olinda
# City not found. Skipping...
# Processing Record 36 of Set 7 | at taj
# City not found. Skipping...
# Processing Record 37 of Set 7 | urengoy
# City not found. Skipping...
# Processing Record 38 of Set 7 | dunedin
# City not found. Skipping...
# Processing Record 39 of Set 7 | dudinka
# City not found. Skipping...
# Processing Record 40 of Set 7 | ulety
# City not found. Skipping...
# Processing Record 41 of Set 7 | masterton
# City not found. Skipping...
# Processing Record 42 of Set 7 | kalaleh
# City not found. Skipping...
# Processing Record 43 of Set 7 | keflavik
# City not found. Skipping...
# Processing Record 44 of Set 7 | san antonio de pale
# City not found. Skipping...
# Processing Record 45 of Set 7 | bereket
# City not found. Skipping...
# Processing Record 46 of Set 7 | fort st. john
# City not found. Skipping...
# Processing Record 47 of Set 7 | dhidhdhoo
# City not found. Skipping...
# Processing Record 48 of Set 7 | kadod
# City not found. Skipping...
# Processing Record 49 of Set 7 | orangeville
# City not found. Skipping...
# Processing Record 0 of Set 8 | gizo
# City not found. Skipping...
# Processing Record 1 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 2 of Set 8 | byron bay
# City not found. Skipping...
# Processing Record 3 of Set 8 | qorovulbozor
# City not found. Skipping...
# Processing Record 4 of Set 8 | shalqar
# City not found. Skipping...
# Processing Record 5 of Set 8 | toyooka
# City not found. Skipping...
# Processing Record 6 of Set 8 | chonchi
# City not found. Skipping...
# Processing Record 7 of Set 8 | anadyr
# City not found. Skipping...
# Processing Record 8 of Set 8 | kemijarvi
# City not found. Skipping...
# Processing Record 9 of Set 8 | avanigadda
# City not found. Skipping...
# Processing Record 10 of Set 8 | hammerfest
# City not found. Skipping...
# Processing Record 11 of Set 8 | callao
# City not found. Skipping...
# Processing Record 12 of Set 8 | kayangel
# City not found. Skipping...
# Processing Record 13 of Set 8 | capitan bado
# City not found. Skipping...
# Processing Record 14 of Set 8 | port sudan
# City not found. Skipping...
# Processing Record 15 of Set 8 | vorkuta
# City not found. Skipping...
# Processing Record 16 of Set 8 | kudymkar
# City not found. Skipping...
# Processing Record 17 of Set 8 | kavieng
# City not found. Skipping...
# Processing Record 18 of Set 8 | patterson
# City not found. Skipping...
# Processing Record 19 of Set 8 | nhamunda
# City not found. Skipping...
# Processing Record 20 of Set 8 | riva del garda
# City not found. Skipping...
# Processing Record 21 of Set 8 | malayer
# City not found. Skipping...
# Processing Record 22 of Set 8 | emerald
# City not found. Skipping...
# Processing Record 23 of Set 8 | da nang
# City not found. Skipping...
# Processing Record 24 of Set 8 | yangor
# City not found. Skipping...
# Processing Record 25 of Set 8 | hobyo
# City not found. Skipping...
# Processing Record 26 of Set 8 | choibalsan
# City not found. Skipping...
# Processing Record 27 of Set 8 | chibougamau
# City not found. Skipping...
# Processing Record 28 of Set 8 | tukrah
# City not found. Skipping...
# Processing Record 29 of Set 8 | tobelo
# City not found. Skipping...
# Processing Record 30 of Set 8 | carbonear
# City not found. Skipping...
# Processing Record 31 of Set 8 | west kelowna
# City not found. Skipping...
# Processing Record 32 of Set 8 | traverse city
# City not found. Skipping...
# Processing Record 33 of Set 8 | tinajo
# City not found. Skipping...
# Processing Record 34 of Set 8 | juye
# City not found. Skipping...
# Processing Record 35 of Set 8 | marksville
# City not found. Skipping...
# Processing Record 36 of Set 8 | pariaman
# City not found. Skipping...
# Processing Record 37 of Set 8 | guadalupe y calvo
# City not found. Skipping...
# Processing Record 38 of Set 8 | cozumel
# City not found. Skipping...
# Processing Record 39 of Set 8 | ta`u
# City not found. Skipping...
# Processing Record 40 of Set 8 | pajara
# City not found. Skipping...
# Processing Record 41 of Set 8 | urucara
# City not found. Skipping...
# Processing Record 42 of Set 8 | pacific grove
# City not found. Skipping...
# Processing Record 43 of Set 8 | tortoli
# City not found. Skipping...
# Processing Record 44 of Set 8 | igrim
# City not found. Skipping...
# Processing Record 45 of Set 8 | puerto baquerizo moreno
# City not found. Skipping...
# Processing Record 46 of Set 8 | luzino
# City not found. Skipping...
# Processing Record 47 of Set 8 | gamay
# City not found. Skipping...
# Processing Record 48 of Set 8 | tanjung selor
# City not found. Skipping...
# Processing Record 49 of Set 8 | nar'yan-mar
# City not found. Skipping...
# Processing Record 0 of Set 9 | atafu village
# City not found. Skipping...
# Processing Record 1 of Set 9 | rio grande
# City not found. Skipping...
# Processing Record 2 of Set 9 | nikolayevsk-on-amure
# City not found. Skipping...
# Processing Record 3 of Set 9 | troy
# City not found. Skipping...
# Processing Record 4 of Set 9 | phek
# City not found. Skipping...
# Processing Record 5 of Set 9 | kununurra
# City not found. Skipping...
# Processing Record 6 of Set 9 | agria
# City not found. Skipping...
# Processing Record 7 of Set 9 | hau-ri
# City not found. Skipping...
# Processing Record 8 of Set 9 | tshabong
# City not found. Skipping...
# Processing Record 9 of Set 9 | east london
# City not found. Skipping...
# Processing Record 10 of Set 9 | starobin
# City not found. Skipping...
# Processing Record 11 of Set 9 | city of balikpapan
# City not found. Skipping...
# Processing Record 12 of Set 9 | dwarka
# City not found. Skipping...
# Processing Record 13 of Set 9 | hadibu
# City not found. Skipping...
# Processing Record 14 of Set 9 | manaure
# City not found. Skipping...
# Processing Record 15 of Set 9 | rio turbio
# City not found. Skipping...
# Processing Record 16 of Set 9 | porrentruy
# City not found. Skipping...
# Processing Record 17 of Set 9 | canete
# City not found. Skipping...
# Processing Record 18 of Set 9 | rabo de peixe
# City not found. Skipping...
# Processing Record 19 of Set 9 | pontes e lacerda
# City not found. Skipping...
# Processing Record 20 of Set 9 | kayyerkan
# City not found. Skipping...
# Processing Record 21 of Set 9 | remire-montjoly
# City not found. Skipping...
# Processing Record 22 of Set 9 | karagandy
# City not found. Skipping...
# Processing Record 23 of Set 9 | greenville
# City not found. Skipping...
# Processing Record 24 of Set 9 | krasnyy chikoy
# City not found. Skipping...
# Processing Record 25 of Set 9 | manadhoo
# City not found. Skipping...
# Processing Record 26 of Set 9 | beyneu
# City not found. Skipping...
# Processing Record 27 of Set 9 | kitimat
# City not found. Skipping...
# Processing Record 28 of Set 9 | haderslev
# City not found. Skipping...
# Processing Record 29 of Set 9 | vingt cinq
# City not found. Skipping...
# Processing Record 30 of Set 9 | richards bay
# City not found. Skipping...
# Processing Record 31 of Set 9 | abong mbang
# City not found. Skipping...
# Processing Record 32 of Set 9 | aykhal
# City not found. Skipping...
# Processing Record 33 of Set 9 | tabuk
# City not found. Skipping...
# Processing Record 34 of Set 9 | muisne
# City not found. Skipping...
# Processing Record 35 of Set 9 | chernyshevskiy
# City not found. Skipping...
# Processing Record 36 of Set 9 | gourdon
# City not found. Skipping...
# Processing Record 37 of Set 9 | alenquer
# City not found. Skipping...
# Processing Record 38 of Set 9 | polyarnyy
# City not found. Skipping...
# Processing Record 39 of Set 9 | najran
# City not found. Skipping...
# Processing Record 40 of Set 9 | copala
# City not found. Skipping...
# Processing Record 41 of Set 9 | cannonvale
# City not found. Skipping...
# Processing Record 42 of Set 9 | karungdong
# City not found. Skipping...
# Processing Record 43 of Set 9 | saint-philippe
# City not found. Skipping...
# Processing Record 44 of Set 9 | afaahiti
# City not found. Skipping...
# Processing Record 45 of Set 9 | coquimbo
# City not found. Skipping...
# Processing Record 46 of Set 9 | zara
# City not found. Skipping...
# Processing Record 47 of Set 9 | aliveri
# City not found. Skipping...
# Processing Record 48 of Set 9 | rantepao
# City not found. Skipping...
# Processing Record 49 of Set 9 | dampit
# City not found. Skipping...
# Processing Record 0 of Set 10 | xianning
# City not found. Skipping...
# Processing Record 1 of Set 10 | malvan
# City not found. Skipping...
# Processing Record 2 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 3 of Set 10 | yendi
# City not found. Skipping...
# Processing Record 4 of Set 10 | praia da vitoria
# City not found. Skipping...
# Processing Record 5 of Set 10 | katsuren-haebaru
# City not found. Skipping...
# Processing Record 6 of Set 10 | trairi
# City not found. Skipping...
# Processing Record 7 of Set 10 | nay pyi taw
# City not found. Skipping...
# Processing Record 8 of Set 10 | palmer
# City not found. Skipping...
# Processing Record 9 of Set 10 | ramnagar
# City not found. Skipping...
# Processing Record 10 of Set 10 | miyazu
# City not found. Skipping...
# Processing Record 11 of Set 10 | bonanza
# City not found. Skipping...
# Processing Record 12 of Set 10 | berezovyy
# City not found. Skipping...
# Processing Record 13 of Set 10 | sungai raya
# City not found. Skipping...
# Processing Record 14 of Set 10 | asmara
# City not found. Skipping...
# Processing Record 15 of Set 10 | freetown
# City not found. Skipping...
# Processing Record 16 of Set 10 | lagunillas
# City not found. Skipping...
# Processing Record 17 of Set 10 | hailar
# City not found. Skipping...
# Processing Record 18 of Set 10 | manali
# City not found. Skipping...
# Processing Record 19 of Set 10 | burhar
# City not found. Skipping...
# Processing Record 20 of Set 10 | tommot
# City not found. Skipping...
# Processing Record 21 of Set 10 | muzayri'
# City not found. Skipping...
# Processing Record 22 of Set 10 | grants
# City not found. Skipping...
# Processing Record 23 of Set 10 | el calafate
# City not found. Skipping...
# Processing Record 24 of Set 10 | yarmouth
# City not found. Skipping...
# Processing Record 25 of Set 10 | auki
# City not found. Skipping...
# Processing Record 26 of Set 10 | jinzhou
# City not found. Skipping...
# Processing Record 27 of Set 10 | karatas
# City not found. Skipping...
# Processing Record 28 of Set 10 | banska bystrica
# City not found. Skipping...
# Processing Record 29 of Set 10 | fale old settlement
# City not found. Skipping...
# Processing Record 30 of Set 10 | angaur state
# City not found. Skipping...
# Processing Record 31 of Set 10 | timiryazevskoye
# City not found. Skipping...
# Processing Record 32 of Set 10 | port saint john's
# City not found. Skipping...
# Processing Record 33 of Set 10 | dawei
# City not found. Skipping...
# Processing Record 34 of Set 10 | alofi
# City not found. Skipping...
# Processing Record 35 of Set 10 | penzance
# City not found. Skipping...
# Processing Record 36 of Set 10 | prienai
# City not found. Skipping...
# Processing Record 37 of Set 10 | rehoboth
# City not found. Skipping...
# Processing Record 38 of Set 10 | hope
# City not found. Skipping...
# Processing Record 39 of Set 10 | berwick-upon-tweed
# City not found. Skipping...
# Processing Record 40 of Set 10 | villa emilio carranza
# City not found. Skipping...
# Processing Record 41 of Set 10 | askoy
# City not found. Skipping...
# Processing Record 42 of Set 10 | prince rupert
# City not found. Skipping...
# Processing Record 43 of Set 10 | kamina
# City not found. Skipping...
# Processing Record 44 of Set 10 | medina
# City not found. Skipping...
# Processing Record 45 of Set 10 | ceeldheer
# City not found. Skipping...
# Processing Record 46 of Set 10 | preobrazheniye
# City not found. Skipping...
# Processing Record 47 of Set 10 | shivpuri
# City not found. Skipping...
# Processing Record 48 of Set 10 | drobak
# City not found. Skipping...
# Processing Record 49 of Set 10 | vernon
# City not found. Skipping...
# Processing Record 0 of Set 11 | pemangkat
# City not found. Skipping...
# Processing Record 1 of Set 11 | new norfolk
# City not found. Skipping...
# Processing Record 2 of Set 11 | pasuquin
# City not found. Skipping...
# Processing Record 3 of Set 11 | tisul'
# City not found. Skipping...
# Processing Record 4 of Set 11 | salalah
# City not found. Skipping...
# Processing Record 5 of Set 11 | faya-largeau
# City not found. Skipping...
# Processing Record 6 of Set 11 | grande prairie
# City not found. Skipping...
# Processing Record 7 of Set 11 | marsh harbour
# City not found. Skipping...
# Processing Record 8 of Set 11 | madison
# City not found. Skipping...
# Processing Record 9 of Set 11 | orapa
# City not found. Skipping...
# Processing Record 10 of Set 11 | kutum
# City not found. Skipping...
# Processing Record 11 of Set 11 | mhamid
# City not found. Skipping...
# Processing Record 12 of Set 11 | khorixas
# City not found. Skipping...
# Processing Record 13 of Set 11 | kaesong
# City not found. Skipping...
# Processing Record 14 of Set 11 | dumai
# City not found. Skipping...
# Processing Record 15 of Set 11 | soure
# City not found. Skipping...
# Processing Record 16 of Set 11 | fortuna
# City not found. Skipping...
# Processing Record 17 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 18 of Set 11 | malango
# City not found. Skipping...
# Processing Record 19 of Set 11 | phan rang-thap cham
# City not found. Skipping...
# Processing Record 20 of Set 11 | powell river
# City not found. Skipping...
# Processing Record 21 of Set 11 | burley
# City not found. Skipping...
# Processing Record 22 of Set 11 | taoudenni
# City not found. Skipping...
# Processing Record 23 of Set 11 | abu jibeha
# City not found. Skipping...
# Processing Record 24 of Set 11 | maridi
# City not found. Skipping...
# Processing Record 25 of Set 11 | kangding
# City not found. Skipping...
# Processing Record 26 of Set 11 | rukban
# City not found. Skipping...
# Processing Record 27 of Set 11 | rongelap
# City not found. Skipping...
# Processing Record 28 of Set 11 | sandnessjoen
# City not found. Skipping...
# Processing Record 29 of Set 11 | cromer
# City not found. Skipping...
# Processing Record 30 of Set 11 | el sauzal de rodriguez
# City not found. Skipping...
# Processing Record 31 of Set 11 | krutinka
# City not found. Skipping...
# Processing Record 32 of Set 11 | montepuez
# City not found. Skipping...
# Processing Record 33 of Set 11 | bayanhongor
# City not found. Skipping...
# Processing Record 34 of Set 11 | labytnangi
# City not found. Skipping...
# Processing Record 35 of Set 11 | zheleznogorsk-ilimskiy
# City not found. Skipping...
# Processing Record 36 of Set 11 | ilhabela
# City not found. Skipping...
# Processing Record 37 of Set 11 | vytegra
# City not found. Skipping...
# Processing Record 38 of Set 11 | ceerigaabo
# City not found. Skipping...
# Processing Record 39 of Set 11 | isangel
# City not found. Skipping...
# Processing Record 40 of Set 11 | inirida
# City not found. Skipping...
# Processing Record 41 of Set 11 | almansa
# City not found. Skipping...
# Processing Record 42 of Set 11 | namibe
# City not found. Skipping...
# Processing Record 43 of Set 11 | nanga eboko
# City not found. Skipping...
# Processing Record 44 of Set 11 | melfort
# City not found. Skipping...
# Processing Record 45 of Set 11 | urcos
# City not found. Skipping...
# Processing Record 46 of Set 11 | yerofey pavlovich
# City not found. Skipping...
# Processing Record 47 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 11 | ocotlan
# City not found. Skipping...
# Processing Record 49 of Set 11 | mora
# City not found. Skipping...
# Processing Record 0 of Set 12 | ust'-talovka
# City not found. Skipping...
# Processing Record 1 of Set 12 | porto velho
# City not found. Skipping...
# Processing Record 2 of Set 12 | sabang
# City not found. Skipping...
# Processing Record 3 of Set 12 | mamuju
# City not found. Skipping...
# Processing Record 4 of Set 12 | tangalle
# City not found. Skipping...
# Processing Record 5 of Set 12 | al hazm
# City not found. Skipping...
# Processing Record 6 of Set 12 | fisterra
# City not found. Skipping...
# Processing Record 7 of Set 12 | morondava
# City not found. Skipping...
# Processing Record 8 of Set 12 | dalhart
# City not found. Skipping...
# Processing Record 9 of Set 12 | saudarkrokur
# City not found. Skipping...
# Processing Record 10 of Set 12 | sinop
# City not found. Skipping...
# Processing Record 11 of Set 12 | arthur's town
# City not found. Skipping...
# Processing Record 12 of Set 12 | chui
# City not found. Skipping...
# Processing Record 13 of Set 12 | zouerate
# City not found. Skipping...
# Processing Record 14 of Set 12 | banda aceh
# City not found. Skipping...
# Processing Record 15 of Set 12 | pascagoula
# City not found. Skipping...
# Processing Record 16 of Set 12 | myitkyina
# City not found. Skipping...
# Processing Record 17 of Set 12 | maibong
# City not found. Skipping...
# Processing Record 18 of Set 12 | merritt island
# City not found. Skipping...
# Processing Record 19 of Set 12 | kalmeshwar
# City not found. Skipping...
# Processing Record 20 of Set 12 | pante makasar
# City not found. Skipping...
# Processing Record 21 of Set 12 | montelimar
# City not found. Skipping...
# Processing Record 22 of Set 12 | nagqu
# City not found. Skipping...
# Processing Record 23 of Set 12 | butembo
# City not found. Skipping...
# Processing Record 24 of Set 12 | oyama
# City not found. Skipping...
# Processing Record 25 of Set 12 | ocsa
# City not found. Skipping...
# Processing Record 26 of Set 12 | ceptura de sus
# City not found. Skipping...
# Processing Record 27 of Set 12 | sherbakul'
# City not found. Skipping...
# Processing Record 28 of Set 12 | canico
# City not found. Skipping...
# Processing Record 29 of Set 12 | sechenovo
# City not found. Skipping...
# Processing Record 30 of Set 12 | flin flon
# City not found. Skipping...
# Processing Record 31 of Set 12 | guthrie
# City not found. Skipping...
# Processing Record 32 of Set 12 | antonio enes
# City not found. Skipping...
# Processing Record 33 of Set 12 | labrador city
# City not found. Skipping...
# Processing Record 34 of Set 12 | matadi
# City not found. Skipping...
# Processing Record 35 of Set 12 | severo-yeniseyskiy
# City not found. Skipping...
# Processing Record 36 of Set 12 | barkly west
# City not found. Skipping...
# Processing Record 37 of Set 12 | baiti
# City not found. Skipping...
# Processing Record 38 of Set 12 | bereznik
# City not found. Skipping...
# Processing Record 39 of Set 12 | nueva gerona
# City not found. Skipping...
# Processing Record 40 of Set 12 | ca mau
# City not found. Skipping...
# Processing Record 41 of Set 12 | point fortin
# City not found. Skipping...
# Processing Record 42 of Set 12 | nuku'alofa
# City not found. Skipping...
# Processing Record 43 of Set 12 | guerrero negro
# City not found. Skipping...
# Processing Record 44 of Set 12 | nova sintra
# City not found. Skipping...
# Processing Record 45 of Set 12 | westport
# City not found. Skipping...
# Processing Record 46 of Set 12 | mont-dore
# City not found. Skipping...
# Processing Record 47 of Set 12 | bikenibeu village
# City not found. Skipping...
# Processing Record 48 of Set 12 | leones
# City not found. Skipping...
# Processing Record 49 of Set 12 | fada
# City not found. Skipping...
# Processing Record 0 of Set 13 | ancud
# City not found. Skipping...
# Processing Record 1 of Set 13 | boden
# City not found. Skipping...
# Processing Record 2 of Set 13 | abadeh
# City not found. Skipping...
# Processing Record 3 of Set 13 | onega
# City not found. Skipping...
# Processing Record 4 of Set 13 | huancavelica
# City not found. Skipping...
# Processing Record 5 of Set 13 | kavaratti
# City not found. Skipping...
# Processing Record 6 of Set 13 | arafat
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# Series([], dtype: int64)

# %%
# Display sample data
city_data_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Export the City_Data into a csv
# ----> 2 city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:734, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732 # Only for write methods
#     733 if "r" not in mode and is_path:
# --> 734     check_parent_directory(str(handle))
#     736 if compression:
#     737     if compression != "zstd":
#     738         # compression libraries do not like an explicit text-mode
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:597, in check_parent_directory(path)
#     595 parent = Path(path).parent
#     596 if not parent.is_dir():
# --> 597     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'output_data'

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Read saved data
# ----> 2 city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")
#       4 # Display sample data
#       5 city_data_df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/cities.csv'

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature °C")
date=city_data_df['Date'].min()
plt.title(f"City Latitude vs. Temperature ({date})")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Build scatter plot for latitude vs. temperature
# ----> 2 plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')
#       4 # Incorporate the other graph properties
#       5 plt.grid()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Lat'

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind='scatter', x='Lat', y='Humidity', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Humidity ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Build the scatter plots for latitude vs. humidity
#       2 city_data_df.plot(kind='scatter', x='Lat', y='Humidity', marker='o', grid=True,\
# ----> 3                   facecolors='b', edgecolors='k', title=f'City Latitude vs. Humidity ({date})')
#       5 # Incorporate the other graph properties
#       6 plt.xlabel("Latitude")
#
# NameError: name 'date' is not defined

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind='scatter', x='Lat', y='Cloudiness', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Cloudiness ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 # Build the scatter plots for latitude vs. cloudiness
#       2 city_data_df.plot(kind='scatter', x='Lat', y='Cloudiness', marker='o', grid=True,\
# ----> 3                   facecolors='b', edgecolors='k', title=f'City Latitude vs. Cloudiness ({date})')
#       5 # Incorporate the other graph properties
#       6 plt.xlabel("Latitude")
#
# NameError: name 'date' is not defined

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind='scatter', x='Lat', y='Wind Speed', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Wind Speed ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Build the scatter plots for latitude vs. wind speed
#       2 city_data_df.plot(kind='scatter', x='Lat', y='Wind Speed', marker='o', grid=True,\
# ----> 3                   facecolors='b', edgecolors='k', title=f'City Latitude vs. Wind Speed ({date})')
#       5 # Incorporate the other graph properties
#       6 plt.xlabel("Latitude")
#
# NameError: name 'date' is not defined

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regress(x, y, eqn_coordinates):
    r = st.pearsonr(x, y)
    print(f"The r-value is: {r[0]}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = f"y ={slope: .2f}x +{intercept: .2f}"
    plt.plot(x, regress_values, "r-")
    plt.annotate(line_eq, eqn_coordinates, fontsize=12, color="red")
    plt.scatter(x, y)
    plt.xlabel(f"{x.name}")
    plt.ylabel(f"{y.name}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# ----> 2 northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]
#       4 # Display sample data
#       5 northern_hemi_df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Lat'

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# ----> 2 southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]
#       4 # Display sample data
#       5 southern_hemi_df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Lat'

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regress(northern_hemi_df["Lat"].rename("Latitude"), northern_hemi_df["Max Temp"], (10, -30))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Linear regression on Northern Hemisphere
# ----> 2 linear_regress(northern_hemi_df["Lat"].rename("Latitude"), northern_hemi_df["Max Temp"], (10, -30))
#
# NameError: name 'northern_hemi_df' is not defined

# %%
# Linear regression on Southern Hemisphere
linear_regress(southern_hemi_df["Lat"].rename("Latitude"), southern_hemi_df["Max Temp"], (-30, 8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Linear regression on Southern Hemisphere
# ----> 2 linear_regress(southern_hemi_df["Lat"].rename("Latitude"), southern_hemi_df["Max Temp"], (-30, 8))
#
# NameError: name 'southern_hemi_df' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress(northern_hemi_df["Lat"].rename("Latitude"), northern_hemi_df["Humidity"], (50, 40))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 # Northern Hemisphere
# ----> 2 linear_regress(northern_hemi_df["Lat"].rename("Latitude"), northern_hemi_df["Humidity"], (50, 40))
#
# NameError: name 'northern_hemi_df' is not defined

# %%
# Southern Hemisphere
linear_regress(southern_hemi_df["Lat"].rename("Latitude"), southern_hemi_df["Humidity"], (-20, 50))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # Southern Hemisphere
# ----> 2 linear_regress(southern_hemi_df["Lat"].rename("Latitude"), southern_hemi_df["Humidity"], (-20, 50))
#
# NameError: name 'southern_hemi_df' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress(northern_hemi_df["Lat"].rename("Latitude"), northern_hemi_df["Cloudiness"], (42, 50))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Northern Hemisphere
# ----> 2 linear_regress(northern_hemi_df["Lat"].rename("Latitude"), northern_hemi_df["Cloudiness"], (42, 50))
#
# NameError: name 'northern_hemi_df' is not defined

# %%
# Southern Hemisphere
linear_regress(southern_hemi_df["Lat"].rename("Latitude"), southern_hemi_df["Cloudiness"], (-50, 50))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Southern Hemisphere
# ----> 2 linear_regress(southern_hemi_df["Lat"].rename("Latitude"), southern_hemi_df["Cloudiness"], (-50, 50))
#
# NameError: name 'southern_hemi_df' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress(northern_hemi_df["Lat"].rename("Latitude"), northern_hemi_df["Wind Speed"], (10, 12))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Northern Hemisphere
# ----> 2 linear_regress(northern_hemi_df["Lat"].rename("Latitude"), northern_hemi_df["Wind Speed"], (10, 12))
#
# NameError: name 'northern_hemi_df' is not defined

# %%
# Southern Hemisphere
linear_regress(southern_hemi_df["Lat"].rename("Latitude"), southern_hemi_df["Wind Speed"], (-50, 9))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Southern Hemisphere
# ----> 2 linear_regress(southern_hemi_df["Lat"].rename("Latitude"), southern_hemi_df["Wind Speed"], (-50, 9))
#
# NameError: name 'southern_hemi_df' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
